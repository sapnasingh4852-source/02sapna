# %% [markdown]
# <a href="https://colab.research.google.com/github/sapnasingh4852-source/02sapna/blob/main/lec1ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello machine")
# Out:
# hello machine

# %%
a = 10
print(a * 2)
# Out:
# 20

# %%
a = 5
b = 10
c = 15
d = 20
e = 25
print(a+b+c+d+e)
# Out:
# 75

# %%
a = input(5)
b = input(10)
c = input(15)
print(a+b+c)

# %%
s = input("Enter a string: ")

rev = ""

for i in s:
    rev = i + rev

if s == rev:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Enter a string: MADAM
# Palindrome
